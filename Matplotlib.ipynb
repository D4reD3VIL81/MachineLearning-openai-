# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('pokemon_data.csv')

# %%
x_points = np.array([0, 3, 200])
y_points = np.array([0, 6, 10])

# %%
plt.bar(x_points, y_points)
plt.xlabel('X')
plt.ylabel('Y')
plt.title("plot")
plt.show()

# %%
x = np.random.normal(170, 10, 250)

plt.hist(x)
plt.show()

# %%
y = np.random.normal(170, 20, 600)

plt.violinplot(y)
plt.show()

# %%
4
